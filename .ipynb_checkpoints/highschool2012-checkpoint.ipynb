# %%
from SubTempNet import *
from edgelist import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
name="highschool2012"

# %% [markdown]
# # Original

# %%
filename = "data/"+name+".edges"
objname= name
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/highschool2012.edges
# objname =	highschool2012_SubTempNet
# directed =	False
# ncount = 	92
# ecount = 	9827
# T = 		49382

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-309c4df575c3> in <module>
#       1 num = 50
# ----> 2 T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
#       3 print(T)
#       4 plt.scatter(T, len(T)*[1])
#       5 plt.xscale("log")
#
# NameError: name 'STN' is not defined

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 7, 9, 11, 14, 17, 21, 27, 34, 42, 52, 66, 82, 102, 128, 159, 199, 248, 309, 385, 480, 599, 747, 931, 1161, 1448, 1806, 2251, 2807, 3500, 4364, 5441, 6783, 8458, 10545, 13147, 16392, 20437, 25480, 31768, 39607]
# Analyzing sample number 1 for samplelength  49382

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.42, 0.165, 0.38, 0.45]
legend = "lower right"
STN.plot_c(legend = legend, inset = inset, I=[4,16], save = name + "_c_rho_ana", vline= vline)
STN.plot_c(legend = legend, inset = inset, I=[4,16], save = name + "_c_rho")

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.42, 0.165, 0.38, 0.45]
legend = "lower right"

STN.plot_c(legend = False, inset = inset, I=[2,4,8,16])
STN.plot_min(I, log = True, T=True, label = name) 
STN.plot_mean(I, log = True, T=True)

# %% [markdown]
# # Edge Time Shuffle

# %%
#create randomized edgelist (edges)
E = TemporalEdgeList("data/"+ name +".edges", directed = False)
E.LST() #shuffel Edges time
E.write("data/"+name+"_ET.edges")

# %%
filename = "data/"+name+"_ET.edges"
objname= name+"_ET"
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/highschool2012_ET.edges
# objname =	highschool2012_ET_SubTempNet
# directed =	False
# ncount = 	92
# ecount = 	9827
# T = 		49378

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 5, 7, 9, 11, 14, 17, 21, 27, 34, 42, 52, 66, 82, 102, 128, 159, 199, 248, 309, 385, 480, 599, 747, 931, 1161, 1448, 1806, 2251, 2807, 3500, 4363, 5440, 6783, 8457, 10544, 13146, 16390, 20435, 25478, 31765, 39604, 49377]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 7, 9, 11, 14, 17, 21, 27, 34, 42, 52, 66, 82, 102, 128, 159, 199, 248, 309, 385, 480, 599, 747, 931, 1161, 1448, 1806, 2251, 2807, 3500, 4363, 5440, 6783, 8457, 10544, 13146, 16390, 20435, 25478]
# Analyzing sample number 3 for samplelength  31765

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.55, 0.4, 0.35, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[2,4,8,16])
STN.plot_min(I, log = True, T=True) 
STN.plot_mean(I, log = True, T=True)

# %% [markdown]
# # Snapshot Time Shuffle

# %%
#create randomized edgelist (snapshots)
E = TemporalEdgeList("data/"+ name +".edges", directed = False)
E.GST() #shuffel snapshot time
E.write("data/"+name+"_ST.edges")

# %%
filename = "data/"+name+"_ST.edges"
objname= name+"_ST"
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/highschool2012_ST.edges
# objname =	highschool2012_ST_SubTempNet
# directed =	False
# ncount = 	92
# ecount = 	9827
# T = 		49380

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 5, 7, 9, 11, 14, 17, 21, 27, 34, 42, 52, 66, 82, 102, 128, 159, 199, 248, 309, 385, 480, 599, 747, 931, 1161, 1448, 1806, 2251, 2807, 3500, 4364, 5441, 6783, 8457, 10544, 13147, 16391, 20436, 25479, 31767, 39606, 49380]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 7, 9, 11, 14, 17, 21, 27, 34, 42, 52, 66, 82, 102, 128, 159, 199, 248, 309, 385, 480, 599, 747, 931, 1161, 1448, 1806, 2251, 2807, 3500, 4364, 5441, 6783, 8457, 10544, 13147, 16391, 20436, 25479, 31767]
# Analyzing sample number 1 for samplelength  39606

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.6, 0.2, 0.37, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_ST_c_rho_ana", vline= vline, linestyle = "--o")

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.55, 0.4, 0.35, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[2,4,8,16])
STN.plot_min(I, log = True, T=True) 
STN.plot_mean(I, log = True, T=True)
