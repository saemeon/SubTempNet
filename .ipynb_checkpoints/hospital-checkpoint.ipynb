# %%
from SubTempNet import *
from edgelist import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
name="hospital"

# %% [markdown]
# # Original

# %%
filename = "data/"+name+".edges"
objname= name
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/hospital.edges
# objname =	hospital_SubTempNet
# directed =	False
# ncount = 	75
# ecount = 	32424
# T = 		17376

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 6, 7, 8, 10, 13, 16, 19, 24, 29, 36, 44, 53, 65, 80, 97, 119, 145, 177, 216, 264, 323, 394, 481, 587, 716, 874, 1067, 1303, 1590, 1941, 2369, 2891, 3529, 4307, 5257, 6416, 7831, 9557, 11665, 14237, 17375]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 6, 7, 8, 10, 13, 16, 19, 24, 29, 36, 44, 53, 65, 80, 97, 119, 145, 177, 216, 264, 323, 394, 481, 587, 716, 874, 1067, 1303, 1590, 1941, 2369, 2891, 3529, 4307, 5257, 6416, 7831, 9557, 11665, 14237]
# Analyzing sample number 1 for samplelength  17375

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
legend = "lower right"
#bbox = (-0.02, 1.05)
bbox = (1.035,-1.35)
STN.plot_cs(legend = False, title = "Hospital",  I=[4,16], bbox = bbox, save = name + "_cr_ana", vline = vline)
STN.plot_cs(legend = legend, title = "Hospital",  I=[4,16], bbox = bbox, save = name + "_cr_ana_leg", vline = vline)

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
legend = "lower right"
#bbox = (-0.02, 1.05)
bbox = (1.035,-1.35)
STN.plot_cs(legend = False, title = "Hospital",  I=[4,16], bbox = bbox, save = False, vline = vline)
STN.plot_cs(legend = legend, title = "Hospital",  I=[4,16], bbox = bbox, save = False, vline = vline)

# %% [markdown]
# # Edge Time Shuffle

# %%
#create randomized edgelist (edges)
E = TemporalEdgeList("data/"+ name +".edges", directed = False)
E.LST() #shuffel Edges time
E.write("data/"+name+"_ET.edges")

# %%
filename = "data/"+name+"_ET.edges"
objname= name+"_ET"
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/hospital_ET.edges
# objname =	hospital_ET_SubTempNet
# directed =	False
# ncount = 	75
# ecount = 	32424
# T = 		17375

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 6, 7, 8, 10, 13, 16, 19, 24, 29, 36, 44, 53, 65, 80, 97, 119, 145, 177, 216, 264, 323, 394, 481, 587, 716, 874, 1067, 1303, 1590, 1941, 2369, 2891, 3529, 4307, 5257, 6416, 7830, 9557, 11664, 14236, 17374]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 6, 7, 8, 10, 13, 16, 19, 24, 29, 36, 44, 53, 65, 80, 97, 119, 145, 177, 216, 264, 323, 394, 481, 587, 716, 874, 1067, 1303, 1590, 1941, 2369, 2891, 3529, 4307]
# Analyzing sample number 5 for samplelength  5257

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
legend = "lower right"
#bbox = (-0.02, 1.05)
bbox = (1.015,-1.25)
STN.plot_cs(legend = None, title = "Random Hospital",  I=[4,16], bbox = bbox, save = name + "_ET_cr_ana", vline = vline)
STN.plot_cs(legend = legend, title = "Random Hospital",  I=[4,16], bbox = bbox, save = name + "_ET_cr_ana_leg", vline = vline)

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
legend = "lower right"
#bbox = (-0.02, 1.05)
bbox = (1.015,-1.23)
STN.plot_cs(legend = None, title = "Random Hospital",  I=[4,16], bbox = bbox, save = False, vline = vline, linestyle = "--^")

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.55, 0.4, 0.35, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[2,4,8,16])
STN.plot_min(I, log = True, T=True) 
STN.plot_mean(I, log = True, T=True)

# %% [markdown]
# # Snapshot Time Shuffle

# %%
#create randomized edgelist (snapshots)
E = TemporalEdgeList("data/"+ name +".edges", directed = False)
E.GST() #shuffel snapshot time
E.write("data/"+name+"_ST.edges")

# %%
filename = "data/"+name+"_ST.edges"
objname= name+"_ST"
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/hospital_ST.edges
# objname =	hospital_ST_SubTempNet
# directed =	False
# ncount = 	75
# ecount = 	32424
# T = 		17375

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 6, 7, 8, 10, 13, 16, 19, 24, 29, 36, 44, 53, 65, 80, 97, 119, 145, 177, 216, 264, 323, 394, 481, 587, 716, 874, 1067, 1303, 1590, 1941, 2369, 2891, 3529, 4307, 5257, 6416, 7830, 9557, 11664, 14236, 17374]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 6, 7, 8, 10, 13, 16, 19, 24, 29, 36, 44, 53, 65, 80, 97, 119, 145, 177, 216, 264, 323, 394, 481, 587, 716, 874, 1067, 1303, 1590, 1941, 2369, 2891]
# Analyzing sample number 5 for samplelength  3529

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
legend = "lower right"
#bbox = (-0.02, 1.05)
bbox = (1.015,-1.23)
STN.plot_cs(legend = legend,  I=[4,16], bbox = bbox, save = name + "_ST_cr_ana", vline = vline, linestyle = "--o")
STN.plot_cs(legend = legend,  I=[4,16], bbox = bbox, save = name + "_ST_cr", vline = False, linestyle = "--o")

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.6, 0.2, 0.37, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_ST_c_rho_ana", vline= vline, linestyle = "--o")

# %%
STN.plot_min(I, log = True, T=True) 
STN.plot_mean(I, log = True, T=True)
