# %% [markdown]
# # ER

# %%
from SubTempNet import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

# %%
#Create Temporal network
n = 100
p = 0.0001
t = 15000
name = "data/ER/ER_ud_n"+str(n)+"_p"+str(p)[2:]+"_T"+str(t)
A = [nx.gnp_random_graph(n, p, seed=None, directed=False) for i in range(t)]
if len(A[0].edges()) ==0:
    u,v = np.random.choice(range(n),2,replace = False )
    A[0].add_edge(u,v)
if len(A[-1].edges()) ==0:
    u,v = np.random.choice(range(n),2,replace = False )
    A[-1].add_edge(u,v)
snapshotlist_to_temporal_edgelist(A, "data/" + name +".edges")

# %%
filepath ="data/ER/ER_ud_n100_p0001_T15000.edges"
objname = "ER_n100_p0001"
STN= SubTempNet(filepath,objname,directed= False, init = False)

# %%
num = 50
T = sorted([1]+list(set(np.logspace(np.log10(2048),np.log10(8.1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
# Out:
# [1, 8, 9, 10, 11, 12, 14, 15, 17, 19, 22, 25, 28, 31, 35, 39, 44, 49, 55, 61, 69, 77, 86, 97, 108, 121, 136, 152, 170, 191, 214, 239, 268, 300, 336, 376, 421, 471, 528, 591, 662, 741, 829, 929, 1040, 1164, 1303, 1459, 1634, 1829, 2048]

# %%
STN.run(*T,  maxsamp = 30, minsamp = 5)
# Out:
# Done with samplelengths  [1, 8, 9, 10, 11, 12, 14, 15, 17, 19, 22, 25, 28, 31, 35, 39, 44, 49, 55, 61, 69, 77, 86, 97, 108, 121, 136, 152, 170, 191, 214, 239, 268, 300, 336, 376, 421, 471, 528, 591, 662, 741, 829, 929, 1040, 1164, 1303, 1459, 1634, 1829]
# Analyzing sample number 7 for samplelength  2048 and  8 slices

# %%
STN.save()

# %%
STN.plot_PA(normalize=True, LCC = False)
STN.plot_LCC(normalize=True, ACC = False)
STN.plot_cA0AT()
STN.plot_cA0AL(2,4,6,8)

# %% [markdown]
# # LCC:

# %% [markdown]
# $PAT = \frac{PAT.nnz}{N^2}$
#
# $LCC = \frac{numnodes(LCC)}{N}$

# %%
STN.plot_LCC(normalize=True, ACC = True)

# %% [markdown]
# $PAT = \frac{PAT.nnz-N}{N^2}$
#
# $LCC = \frac{numnodes(LCC)}{N}$

# %%
STN.plot_LCC(normalize=True, ACC = True)

# %% [markdown]
# $PAT = (\frac{PAT.nnz}{N^2})^{0.5}$
#
# $LCC = \frac{numnodes(LCC)}{N}$

# %%
STN.plot_LCC(normalize=True, ACC = True)

# %% [markdown]
# $PAT = (\frac{PAT.nnz-N}{N^2})^{0.5}$
#
# $LCC = \frac{numnodes(LCC)}{N}$

# %%
STN.plot_LCC(normalize=True, ACC = True)

# %% [markdown]
# $PAT = \frac{PAT.nnz}{N^2}$
#
# $LCC = (\frac{numnodes(LCC)}{N})^2$

# %%
STN.plot_LCC(normalize=True, ACC = True)

# %% [markdown]
# $PAT = \frac{PAT.nnz-N}{N^2}$
#
# $LCC = (\frac{numnodes(LCC)}{N})^2$

# %%
STN.plot_LCC(normalize=True, ACC = True)
