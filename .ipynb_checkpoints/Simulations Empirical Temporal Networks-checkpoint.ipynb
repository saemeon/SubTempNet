# %% [markdown]
# # Empirical Temporal Networks

# %%
from SubTempNet import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Primaryschool

# %% [markdown]
# ## Original

# %%
filename = "data/primaryschool.edges"
objname= "primaryschool"
STN = SubTempNet(filename, objname, directed= False, init = False)

# %%
num = 50
T = sorted([1]+list(set(np.logspace(np.log10(STN["T"]),np.log10(8.1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
# Out:
# [1, 8, 9, 10, 12, 13, 15, 18, 20, 23, 27, 31, 35, 40, 46, 53, 60, 69, 79, 90, 103, 118, 135, 155, 177, 203, 232, 266, 304, 348, 398, 455, 521, 595, 681, 779, 891, 1019, 1166, 1334, 1525, 1745, 1996, 2283, 2611, 2986, 3416, 3907, 4468, 5111, 5846]

# %%
STN.run(*T,  maxsamp = 30, minsamp = 5)
# Out:
# Done with samplelengths  [1, 8, 9, 10, 12, 13, 15, 18, 20, 23, 27, 31, 35, 40, 46, 53, 60, 69, 79, 90, 103, 118, 135, 155, 177, 203, 232, 266, 304, 348, 398, 455, 521, 595, 681, 779, 891, 1019, 1166, 1334, 1525, 1745, 1996, 2283, 2611, 2986, 3416, 3907, 4468, 5111]
# Analyzing sample number 1 for samplelength  5846 and  8 slices

# %%
STN.save()

# %%
STN.plot_PA(normalize=True, LCC = False)
STN.plot_LCC(normalize=True, ACC = False)
STN.plot_cA0AT()
STN.plot_cA0AL(5,10,15,20,25,30)

# %% [markdown]
# ## EDS

# %%
#Create EDS Temporal network
name = "data/"+ STN["objname"][:-11]+"_EDS.edges"
deg = STN["deg_seq"]/STN["T"]
A = []
for t in range(int(1.5*STN["T"])):
    A.append(STN.ChungLu(deg))
#check that first and last snapshot contain at least one edge
if len(A[0].edges()) ==0:
    u,v = np.random.choice(range(n),2,replace = False )
    A[0].add_edge(u,v)
if len(A[-1].edges()) ==0:
    u,v = np.random.choice(range(n),2,replace = False )
    A[-1].add_edge(u,v)
#save edgelist
SubTempNet.write_snapshotlist_to_edgelist(A, name, separator='\t')

# %%
filename = "data/primaryschool_EDS.edges"
objname= "primaryschool_EDS"
STN = SubTempNet(filename, objname, directed= False, init = False)

# %%
num = 50
T = sorted([1]+list(set(np.logspace(np.log10(5846),np.log10(8.1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
# Out:
# [1, 8, 9, 10, 12, 13, 15, 18, 20, 23, 27, 31, 35, 40, 46, 53, 60, 69, 79, 90, 103, 118, 135, 155, 177, 203, 232, 266, 304, 348, 398, 455, 521, 595, 681, 779, 891, 1019, 1166, 1334, 1525, 1745, 1996, 2283, 2611, 2986, 3416, 3907, 4468, 5111, 5846]

# %%
STN.run(*T,  maxsamp = 30, minsamp = 5)
# Out:
# Done with samplelengths  [1, 8, 9, 10, 12, 13, 15, 18, 20, 23, 27, 31, 35, 40, 46, 53, 60, 69, 79, 90, 103, 118, 135, 155, 177]
# Analyzing sample number 30 for samplelength  203 and  8 slices

# %%
STN.save()

# %%
STN.plot_PA(normalize=True, LCC = False)
STN.plot_LCC(normalize=True, ACC = False)
STN.plot_cA0AT()
STN.plot_cA0AL(2,4,6,8)

# %%
STN.run(1,2,3,4,5,6,7,8,  maxsamp = 30, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 6, 7]
# Analyzing sample number 31 for samplelength  8 and  8 slices

# %%
STN.plot_cA0AT()

# %%
STN.plot_PA(normalize=True, LCC = False)
STN.plot_LCC(normalize=True, ACC = False)
STN.plot_cA0AT()
STN.plot_cA0AL(2,4,6,8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-72e1a225bc99> in <module>
#       2 STN.plot_LCC(normalize=True, ACC = False)
#       3 STN.plot_cA0AT()
# ----> 4 STN.plot_cA0AL(2,4,6,8)
#
# ~\OneDrive\Dokumente\SubTempNet\SubTempNet.py in plot_cA0AL(self, save, *T)
#     365         linestyle = "--*"
#     366         for t in T:
# --> 367             ax.plot([x[t],x[t]/2,x[t]/4,x[t]/8,1],[list(np.array(PA0)/np.array(PAT))[t],list(np.array(PA0)/np.array(PAT2))[t],list(np.array(PA0)/np.array(PAT4))[t],list(np.array(PA0)/np.array(PAT8))[t],1],linestyle, label = "T= "+str(x[t]))
#     368         ax.legend()
#     369         fig.tight_layout()
#
# ValueError: operands could not be broadcast together with shapes (56,) (54,)

# %%
del STN["PAT8"][1]

# %%
STN.plot_PA(normalize=True, LCC = False)
