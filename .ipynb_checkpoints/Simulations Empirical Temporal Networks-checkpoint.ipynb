# %% [markdown]
# # Empirical Temporal Networks

# %%
from SubTempNet import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Primaryschool

# %% [markdown]
# ## Original

# %%
filename = "data/primaryschool.edges"
objname= "primaryschool"
STN = SubTempNet(filename, objname, directed= False, init = False)

# %%
d1 =STN["deg_seq"] /STN["T"]

# %%
num = 50
T = sorted([1]+list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
# Out:
# [1, 1, 2, 3, 4, 5, 6, 7, 9, 11, 13, 16, 19, 23, 28, 33, 40, 48, 58, 70, 85, 102, 123, 148, 179, 215, 259, 312, 375, 452, 544, 655, 788, 949, 1142, 1374, 1654, 1991, 2397, 2884, 3472, 4179, 5029, 6053, 7285, 8769]

# %%
STN.run(*T,  maxsamp = 30, minsamp = 5)
# Out:
# Done with samplelengths  [1, 8, 9, 10, 12, 13, 15, 18, 20, 23, 27, 31, 35, 40, 46, 53, 60, 69, 79, 90, 103, 118, 135, 155, 177, 203, 232, 266, 304, 348, 398, 455, 521, 595, 681, 779, 891, 1019, 1166, 1334, 1525, 1745, 1996, 2283, 2611, 2986, 3416, 3907, 4468, 5111]
# Analyzing sample number 1 for samplelength  5846 and  8 slices

# %%
STN.save()

# %%
STN.plot_PA(normalize=True, LCC = False)
STN.plot_LCC(normalize=True, ACC = False)
STN.plot_cA0AT()
STN.plot_cA0AL(5,10,15,20,25,30)

# %% [markdown]
# ## EDS

# %%
#Create EDS Temporal network
name = "data/"+ STN["objname"][:-11]+"_EDS.edges"
deg = STN["deg_seq"]/STN["T"]
A = []
for t in range(int(1.5*STN["T"])):
    A.append(STN.ChungLu(deg))
#check that first and last snapshot contain at least one edge
if len(A[0].edges()) ==0:
    u,v = np.random.choice(range(n),2,replace = False )
    A[0].add_edge(u,v)
if len(A[-1].edges()) ==0:
    u,v = np.random.choice(range(n),2,replace = False )
    A[-1].add_edge(u,v)
#save edgelist
SubTempNet.write_snapshotlist_to_edgelist(A, name, separator='\t')

# %%
filename = "data/primaryschool_EDS.edges"
objname= "primaryschool_EDS"
STN = SubTempNet(filename, objname, directed= False, init = False)

# %%
d2 =STN["deg_seq"] / STN["T"]

# %%
num = 50
T = sorted([1]+list(set(np.logspace(np.log10(5846),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
# Out:
# [1, 1, 2, 3, 4, 5, 7, 8, 9, 11, 14, 16, 20, 24, 28, 34, 41, 49, 58, 69, 83, 99, 119, 142, 169, 202, 241, 288, 344, 410, 490, 585, 698, 834, 995, 1188, 1418, 1693, 2021, 2412, 2879, 3437, 4103, 4897, 5846]

# %%
STN.run(*T,  maxsamp = 30, minsamp = 5)
# Out:
# Done with samplelengths  [1, 8, 9, 10, 12, 13, 15, 18, 20, 23, 27, 31, 35, 40, 46, 53, 60, 69, 79, 90, 103, 118, 135, 155, 177]
# Analyzing sample number 30 for samplelength  203 and  8 slices

# %%
STN.save()

# %%
STN.plot_PA(normalize=True, LCC = False)
STN.plot_LCC(normalize=True, ACC = False)
STN.plot_cA0AT()
STN.plot_cA0AL(2,4,6,8)

# %%
plt.plot(d2/2)
plt.plot(d1)
plt.show()

# %% [markdown]
# # Highschool 2012

# %% [markdown]
# ## Original

# %%
filename = "data/highschool2012.edges"
objname= "highschool2012"
STN = SubTempNet(filename, objname, directed= True, init = False)

# %%
print(STN)
# Out:
# filename =	data/highschool2012.edges
# objname =	highschool2012_SubTempNet
# directed =	True
# ncount = 	92
# ecount = 	9827
# T = 		49382

# %%
num = 50
T = sorted([1]+list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
# Out:
# [1, 1, 2, 3, 4, 5, 7, 9, 11, 14, 17, 21, 27, 34, 42, 52, 66, 82, 102, 128, 159, 199, 248, 309, 385, 480, 599, 747, 931, 1161, 1448, 1806, 2251, 2807, 3500, 4364, 5441, 6783, 8458, 10545, 13147, 16392, 20437, 25480, 31768, 39607, 49382]

# %%
STN.run(*T,  maxsamp = 30, minsamp = 5)
# Out:
# Done with samplelengths  [1, 1, 2, 3, 4, 5, 7, 9, 11, 14, 17, 21, 27, 34, 42, 52, 66, 82, 102, 128, 159, 199, 248, 309, 385, 480, 599, 747, 931, 1161, 1448, 1806, 2251, 2807, 3500, 4364, 5441, 6783, 8458, 10545, 13147, 16392, 20437, 25480, 31768, 39607]
# Analyzing sample number 1 for samplelength  49382 and  8 slices

# %%
STN.save()

# %%
STN.plot_PA(normalize=True, LCC = False)
STN.plot_LCC(normalize=True, ACC = False)
STN.plot_cA0AT()
STN.plot_cA0AL(5,10,15,20,25,30)

# %% [markdown]
# ## EDS

# %%
#Create EDS Temporal network
name = "data/"+ STN["objname"][:-11]+"_EDS.edges"
deg = STN["deg_seq"]/STN["T"]
A = []
for t in range(int(1.5*STN["T"])):
    A.append(STN.ChungLu(deg))
#check that first and last snapshot contain at least one edge
if len(A[0].edges()) ==0:
    u,v = np.random.choice(range(n),2,replace = False )
    A[0].add_edge(u,v)
if len(A[-1].edges()) ==0:
    u,v = np.random.choice(range(n),2,replace = False )
    A[-1].add_edge(u,v)
#save edgelist
SubTempNet.write_snapshotlist_to_edgelist(A, name, separator='\t')

# %%
filename = "data/highschool2012_EDS.edges"
objname= "highschool2012_EDS"
STN = SubTempNet(filename, objname, directed= False, init = False)

# %%
print(STN)
# Out:
# filename =	data/highschool2012_EDS.edges
# objname =	highschool2012_EDS_SubTempNet
# directed =	False
# ncount = 	92
# ecount = 	14237
# T = 		74073

# %%
STN.run(*T,  maxsamp = 30, minsamp = 5)
# Out:
# Done with samplelengths  [1, 1, 2, 3, 4, 5, 7, 9, 11, 14, 17, 21, 27, 34, 42, 52, 66, 82, 102, 128, 159, 199, 248, 309, 385, 480, 599, 747, 931, 1161, 1448, 1806, 2251, 2807, 3500, 4364, 5441, 6783, 8458, 10545, 13147, 16392, 20437, 25480, 31768, 39607]
# Analyzing sample number 3 for samplelength  49382 and  8 slices

# %%
STN.save()

# %%
STN.plot_PA(normalize=True, LCC = False)
STN.plot_LCC(normalize=True, ACC = False)
STN.plot_cA0AT()
STN.plot_cA0AL(10,20,30,40)

# %% [markdown]
# # LOTR

# %% [markdown]
# ## Original

# %%
filename = "data/lotr.edges"
objname= "lotr"
STN = SubTempNet(filename, objname, directed= False, init = False)

# %%
print(STN)
# Out:
# filename =	data/lotr.edges
# objname =	lotr_SubTempNet
# directed =	False
# ncount = 	139
# ecount = 	2649
# T = 		32642

# %%
d1 =STN["deg_seq"]

# %%
# Out:
# 139

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
# Out:
# [1, 2, 3, 4, 5, 6, 8, 10, 12, 15, 19, 24, 29, 36, 45, 56, 69, 85, 106, 131, 162, 200, 248, 307, 379, 469, 580, 717, 886, 1096, 1355, 1675, 2071, 2560, 3165, 3913, 4838, 5981, 7395, 9142, 11302, 13973, 17275, 21357, 26403, 32641]

# %%
STN.run(*T,  maxsamp = 30, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 6, 8, 10, 12, 15, 19, 24, 29, 36, 45, 56, 69, 85, 106, 131, 162, 200, 248, 307, 379, 469, 580, 717, 886, 1096, 1355, 1675, 2071, 2560, 3165, 3913, 4838, 5981, 7395, 9142, 11302, 13973, 17275, 21357, 26403]
# Analyzing sample number 1 for samplelength  32641 and  8 slices

# %%
STN.save()

# %%
STN.plot_PA(normalize=True, LCC = False)
STN.plot_LCC(normalize=True, ACC = False)
STN.plot_cA0AT()
STN.plot_cA0AL(5,10,15,20,25,30)

# %%
STN.plot_PA(normalize=True, LCC = False)
STN.plot_LCC(normalize=True, ACC = False)
STN.plot_cA0AT()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\ma\core.py:6666: RuntimeWarning: underflow encountered in power
#   result = np.where(m, fa, umath.power(fa, fb)).view(basetype)

# %% [markdown]
# ## EDS

# %%
#Create EDS Temporal network
name = "data/"+ STN["objname"][:-11]+"_EDS.edges"
deg = STN["deg_seq"]/STN["T"]
A = []
for t in range(int(1.5*STN["T"])):
    A.append(STN.ChungLu(deg))
#check that first and last snapshot contain at least one edge
if len(A[0].edges()) ==0:
    u,v = np.random.choice(range(STN["ncount"]),2,replace = False )
    A[0].add_edge(u,v)
if len(A[-1].edges()) ==0:
    u,v = np.random.choice(range(STN["ncount"]),2,replace = False )
    A[-1].add_edge(u,v)
#save edgelist
SubTempNet.write_snapshotlist_to_edgelist(A, name, separator='\t')

# %%
filename = "data/lotr_EDS.edges"
objname= "lotr_EDS"
STN = SubTempNet(filename, objname, directed= False, init = True)

# %%
print(STN)
# Out:
# filename =	data/lotr_EDS.edges
# objname =	lotr_EDS_SubTempNet
# directed =	False
# ncount = 	139
# ecount = 	7491
# T = 		48963

# %%
STN.save()

# %%
d2 = STN["deg_seq"] / 1.5

# %%
plt.plot(d2, label = "EDS")
plt.plot(d1, label = "original")
plt.legend()

# %%
plt.plot(d2/d1, label = "EDS")

# %%
print(STN)
# Out:
# filename =	data/lotr_EDS.edges
# objname =	lotr_EDS_SubTempNet
# directed =	False
# ncount = 	137
# ecount = 	7734
# T = 		48963

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
# Out:
# [1, 2, 3, 4, 5, 6, 8, 10, 12, 15, 19, 24, 29, 36, 45, 56, 69, 85, 106, 131, 162, 200, 248, 307, 379, 469, 580, 717, 886, 1096, 1355, 1675, 2071, 2560, 3165, 3913, 4838, 5981, 7395, 9142, 11302, 13973, 17275, 21357, 26403, 32641]

# %%
STN.run(*T,  maxsamp = 30, minsamp = 5)
# Out:
# Done with samplelengths  [1, 1, 2, 3, 4, 5, 7, 9, 11, 14, 17, 21, 27, 34, 42, 52, 66, 82, 102, 128, 159, 199, 248, 309, 385, 480, 599, 747, 931, 1161, 1448, 1806, 2251, 2807, 3500, 4364, 5441, 6783, 8458, 10545, 13147, 16392, 20437, 25480, 31768, 39607]
# Analyzing sample number 3 for samplelength  49382 and  8 slices

# %%
STN.save()

# %%
STN.plot_PA(normalize=True, LCC = False)
STN.plot_LCC(normalize=True, ACC = False)
STN.plot_cA0AT()
STN.plot_cA0AL(10,20,30,40)
