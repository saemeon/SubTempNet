# %%
from SubTempNet import *
from edgelist import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
name="hypertext"

# %% [markdown]
# # Original

# %%
filename = "data/"+name+".edges"
objname= name
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/hypertext.edges
# objname =	hypertext_SubTempNet
# directed =	False
# ncount = 	113
# ecount = 	20818
# T = 		10618

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 17, 20, 24, 30, 36, 43, 53, 64, 77, 93, 113, 136, 165, 199, 241, 291, 352, 425, 514, 621, 751, 907, 1096, 1325, 1601, 1934, 2337, 2824, 3412, 4123, 4981, 6019, 7273, 8787, 10618]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 17, 20, 24, 30, 36, 43, 53, 64, 77, 93, 113, 136, 165, 199, 241, 291, 352, 425, 514, 621, 751, 907, 1096, 1325, 1601, 1934, 2337, 2824, 3412, 4123, 4981, 6019, 7273, 8787]
# Analyzing sample number 1 for samplelength  10618

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
legend = "lower right"
#bbox = (-0.02, 1.05)
bbox = (1.015,-1.28)
STN.plot_cs(legend = False,  I=[4,16], bbox = bbox, save = name + "_cr_ana", vline = vline)
STN.plot_cs(legend = legend,  I=[4,16], bbox = bbox, save = name + "_cr", vline = False)

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.42, 0.165, 0.38, 0.45]
legend = "lower right"
STN.plot_c(legend = legend, inset = inset, I=[4,16], save = name + "_c_rho_ana", vline= vline)
STN.plot_c(legend = legend, inset = inset, I=[4,16], save = name + "_c_rho")

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.42, 0.165, 0.38, 0.45]
legend = "lower right"

STN.plot_c(legend = False, inset = inset, I=[2,4,8,16])
STN.plot_min(I, log = True, T=True, label = name) 
STN.plot_mean(I, log = True, T=True)

# %% [markdown]
# # Edge Time Shuffle

# %%
#create randomized edgelist (edges)
E = TemporalEdgeList("data/"+ name +".edges", directed = False)
E.LST() #shuffel Edges time
E.write("data/"+name+"_ET.edges")

# %%
filename = "data/"+name+"_ET.edges"
objname= name+"_ET"
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/hypertext_ET.edges
# objname =	hypertext_ET_SubTempNet
# directed =	False
# ncount = 	113
# ecount = 	20818
# T = 		10618

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 17, 20, 24, 30, 36, 43, 53, 64, 77, 93, 113, 136, 165, 199, 241, 291, 352, 425, 514, 621, 751, 907, 1096, 1325, 1601, 1934, 2337, 2824, 3412, 4123, 4981, 6019, 7273, 8787, 10618]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 17, 20, 24, 30, 36, 43, 53, 64, 77, 93, 113, 136, 165, 199, 241, 291, 352, 425, 514, 621, 751, 907, 1096, 1325, 1601, 1934, 2337, 2824, 3412]
# Analyzing sample number 5 for samplelength  4123

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
legend = "lower right"
#bbox = (-0.02, 1.05)
bbox = (1.015,-1.23)
STN.plot_cs(legend = False,  I=[4,16], bbox = bbox, save = name + "_ET_cr_ana", vline = vline, linestyle = "--^")
STN.plot_cs(legend = legend,  I=[4,16], bbox = bbox, save = name + "_ET_cr", vline = False, linestyle = "--^")

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.55, 0.2, 0.4, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_ET_c_rho", linestyle = "--^")
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_ET_c_rho_ana", vline= vline, linestyle = "--^")

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.55, 0.4, 0.35, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[2,4,8,16])
STN.plot_min(I, log = True, T=True) 
STN.plot_mean(I, log = True, T=True)

# %% [markdown]
# # Snapshot Time Shuffle

# %%
#create randomized edgelist (snapshots)
E = TemporalEdgeList("data/"+ name +".edges", directed = False)
E.GST() #shuffel snapshot time
E.write("data/"+name+"_ST.edges")

# %%
filename = "data/"+name+"_ST.edges"
objname= name+"_ST"
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/hypertext_ST.edges
# objname =	hypertext_ST_SubTempNet
# directed =	False
# ncount = 	113
# ecount = 	20818
# T = 		10611

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 17, 20, 24, 30, 36, 43, 53, 64, 77, 93, 113, 136, 165, 199, 241, 291, 352, 425, 514, 621, 750, 907, 1096, 1324, 1600, 1933, 2336, 2822, 3410, 4120, 4978, 6015, 7268, 8782, 10610]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 17, 20, 24, 30, 36, 43, 53, 64, 77, 93, 113, 136, 165, 199, 241, 291, 352, 425, 514, 621, 750, 907, 1096, 1324, 1600, 1933, 2336, 2822, 3410, 4120, 4978, 6015]
# Analyzing sample number 2 for samplelength  7268

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
legend = "lower right"
#bbox = (-0.02, 1.05)
bbox = (1.015,-1.23)
STN.plot_cs(legend = legend,  I=[4,16], bbox = bbox, save = name + "_ST_cr_ana", vline = vline, linestyle = "--o")
STN.plot_cs(legend = legend,  I=[4,16], bbox = bbox, save = name + "_ST_cr", vline = False, linestyle = "--o")

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.61, 0.2, 0.37, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_ST_c_rho_ana", vline= vline, linestyle = "--o")

# %%
STN.plot_min(I, log = True, T=True) 
STN.plot_mean(I, log = True, T=True)
