# %%
from SubTempNet import *
from edgelist import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
name="SFHH"

# %% [markdown]
# # Original

# %%
filename = "data/"+name+".edges"
objname= name
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/SFHH.edges
# objname =	SFHH_SubTempNet
# directed =	False
# ncount = 	403
# ecount = 	70261
# T = 		5716

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 16, 20, 23, 28, 34, 40, 48, 58, 69, 82, 98, 117, 140, 167, 199, 238, 284, 339, 404, 482, 575, 687, 819, 977, 1166, 1392, 1660, 1981, 2364, 2820, 3365, 4015, 4790, 5715]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 10)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 16, 20, 23, 28, 34, 40, 48, 58, 69, 82, 98, 117, 140, 167, 199, 238, 284, 339, 404, 482, 575, 687, 819, 977, 1166, 1392, 1660, 1981, 2364, 2820, 3365, 4015, 4790]
# Analyzing sample number 1 for samplelength  5715

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.42, 0.165, 0.38, 0.45]
legend = "lower right"
STN.plot_c(legend = legend, inset = inset, I=[4,16], save = name + "_c_rho_ana", vline= vline)
STN.plot_c(legend = legend, inset = inset, I=[4,16], save = name + "_c_rho")

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.42, 0.165, 0.38, 0.45]
legend = "lower right"

STN.plot_c(legend = False, inset = inset, I=[2,4,8,16])
STN.plot_min(I, log = True, T=True, label = name) 
STN.plot_mean(I, log = True, T=True)

# %% [markdown]
# # Edge Time Shuffle

# %%
#create randomized edgelist (edges)
E = TemporalEdgeList("data/"+ name +".edges", directed = False)
E.LST() #shuffel Edges time
E.write("data/"+name+"_ET.edges")

# %%
filename = "data/"+name+"_ET.edges"
objname= name+"_ET"
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/SFHH_ET.edges
# objname =	SFHH_ET_SubTempNet
# directed =	False
# ncount = 	403
# ecount = 	70261
# T = 		5716

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 16, 20, 23, 28, 34, 40, 48, 58, 69, 82, 98, 117, 140, 167, 199, 238, 284, 339, 404, 482, 575, 687, 819, 977, 1166, 1392, 1660, 1981, 2364, 2820, 3365, 4015, 4790, 5715]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 16, 20, 23, 28, 34, 40, 48, 58, 69, 82, 98, 117, 140, 167, 199, 238, 284, 339, 404, 482, 575, 687, 819, 977, 1166, 1392, 1660, 1981, 2364, 2820, 3365]
# Analyzing sample number 2 for samplelength  4015

# %%
STN.save()

# %%
  p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.55, 0.2, 0.4, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_ET_c_rho", linestyle = "--^")
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_ET_c_rho_ana", vline= vline, linestyle = "--^")

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.55, 0.4, 0.35, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[2,4,8,16])
STN.plot_min(I, log = True, T=True) 
STN.plot_mean(I, log = True, T=True)

# %% [markdown]
# # Snapshot Time Shuffle

# %%
#create randomized edgelist (snapshots)
E = TemporalEdgeList("data/"+ name +".edges", directed = False)
E.GST() #shuffel snapshot time
E.write("data/"+name+"_ST.edges")

# %%
filename = "data/"+name+"_ST.edges"
objname= name+"_ST"
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/SFHH_ST.edges
# objname =	SFHH_ST_SubTempNet
# directed =	False
# ncount = 	403
# ecount = 	70261
# T = 		5714

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 16, 20, 23, 28, 34, 40, 48, 58, 69, 82, 98, 117, 140, 167, 199, 238, 284, 338, 404, 482, 575, 686, 819, 977, 1166, 1391, 1660, 1981, 2363, 2820, 3364, 4014, 4789, 5713]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 6, 8, 9, 11, 14, 16, 20, 23, 28, 34, 40, 48, 58, 69, 82, 98, 117, 140, 167, 199, 238, 284, 338, 404, 482, 575, 686, 819, 977, 1166, 1391, 1660, 1981, 2363, 2820, 3364]
# Analyzing sample number 2 for samplelength  4014

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.6, 0.2, 0.37, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_ST_c_rho_ana", vline= vline, linestyle = "--o")

# %%
STN.plot_min(I, log = True, T=True) 
STN.plot_mean(I, log = True, T=True)
