# %%
from SubTempNet import *
from edgelist import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
name="primaryschool"

# %% [markdown]
# # Original

# %%
filename = "data/"+name+".edges"
objname= name
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/primaryschool.edges
# objname =	primaryschool_SubTempNet
# directed =	False
# ncount = 	242
# ecount = 	125773
# T = 		5846

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 5, 7, 8, 9, 11, 14, 16, 20, 24, 28, 34, 41, 49, 58, 69, 83, 99, 119, 142, 169, 202, 241, 288, 344, 410, 490, 585, 698, 834, 995, 1188, 1418, 1693, 2021, 2412, 2879, 3437, 4103, 4897, 5846]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 7, 8, 9, 11, 14, 16, 20, 24, 28, 34, 41, 49, 58, 69, 83, 99, 119, 142, 169, 202, 241, 288, 344, 410, 490, 585, 698, 834, 995, 1188, 1418, 1693, 2021, 2412, 2879, 3437, 4103, 4897]
# Analyzing sample number 1 for samplelength  5846

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.5, 0.165, 0.4, 0.45]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_c_rho_ana", vline= vline)
STN.plot_c(legend = False , inset = inset, I=[4,16], save = name + "_c_rho")

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.42, 0.165, 0.38, 0.45]
legend = "lower right"
STN.plot_c(legend = legend, inset = inset, I=[4,16], save = name + "_c_rho_ana_leg", vline= vline)
STN.plot_c(legend = legend, inset = inset, I=[4,16], save = name + "_c_rho_leg")
STN.plot_cA0AT(legend = legend, rho = False, save = name + "_c_leg")

# %%
STN.plot_c(legend = legend, I=[4,16],inset = True, save = name + "_c_leg")

# %%
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
STN.plot_min(I, log = True, T=True, label = name) 
STN.plot_mean(I, log = True, T=True)

# %% [markdown]
# # Edge Time Shuffle

# %%
#create randomized edgelist (edges)
E = TemporalEdgeList("data/"+ name +".edges", directed = False)
E.LST() #shuffel Edges time
E.write("data/"+name+"_ET.edges")

# %%
filename = "data/"+name+"_ET.edges"
objname= name+"_ET"
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/primaryschool_ET.edges
# objname =	primaryschool_ET_SubTempNet
# directed =	False
# ncount = 	242
# ecount = 	125773
# T = 		5846

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 5, 7, 8, 9, 11, 14, 16, 20, 24, 28, 34, 41, 49, 58, 69, 83, 99, 119, 142, 169, 202, 241, 288, 344, 410, 490, 585, 698, 834, 995, 1188, 1418, 1693, 2021, 2412, 2879, 3437, 4103, 4897, 5846]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 7, 8, 9, 11, 14, 16, 20, 24, 28, 34, 41, 49, 58, 69, 83, 99, 119, 142, 169, 202, 241, 288]
# Analyzing sample number 16 for samplelength  344

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.55, 0.2, 0.4, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_ET_c_rho", linestyle = "--^")
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_ET_c_rho_ana", vline= vline, linestyle = "--^")

# %%
STN.plot_min(I, log = True, T=True) 
STN.plot_mean(I, log = True, T=True)

# %% [markdown]
# # Snapshot Time Shuffle

# %%
#create randomized edgelist (snapshots)
E = TemporalEdgeList("data/"+ name +".edges", directed = False)
E.GST() #shuffel snapshot time
E.write("data/"+name+"_ST.edges")

# %%
filename = "data/"+name+"_ST.edges"
objname= name+"_ST"
STN = SubTempNet(filename, objname, directed= False, init = False)
print(STN)
# Out:
# filename =	data/primaryschool_ST.edges
# objname =	primaryschool_ST_SubTempNet
# directed =	False
# ncount = 	242
# ecount = 	125773
# T = 		5846

# %%
num = 50
T = sorted(list(set(np.logspace(np.log10(STN["T"]),np.log10(1), num, dtype = int))))
print(T)
plt.scatter(T, len(T)*[1])
plt.xscale("log")
I = [2** i for i in range(1,int(np.log2(STN["T"])+1))]
print(I)
# Out:
# [1, 2, 3, 4, 5, 7, 8, 9, 11, 14, 16, 20, 24, 28, 34, 41, 49, 58, 69, 83, 99, 119, 142, 169, 202, 241, 288, 344, 410, 490, 585, 698, 834, 995, 1188, 1418, 1693, 2021, 2412, 2879, 3437, 4103, 4897, 5846]
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]

# %%
STN.run2(I, T,  maxsamp = 50, minsamp = 5)
# Out:
# Done with samplelengths  [1, 2, 3, 4, 5, 7, 8, 9, 11, 14, 16, 20, 24, 28, 34, 41, 49, 58, 69, 83, 99, 119, 142, 169, 202, 241, 288, 344]
# Analyzing sample number 14 for samplelength  410

# %%
STN.save()

# %%
p=np.mean(STN["deg_seq"])/STN["T"]/(STN["ncount"]-1)
n= STN["ncount"]
vline=[(STN.TC1(n,p), "blue" , None),
       (STN.TC2(n,p), "red", None)]
inset = [0.6, 0.2, 0.37, 0.4]
legend = "lower right"
STN.plot_c(legend = False, inset = inset, I=[4,16], save = name + "_ST_c_rho_ana", vline= vline, linestyle = "--o")

# %%
STN.plot_min(I, log = True, T=True) 
STN.plot_mean(I, log = True, T=True)
